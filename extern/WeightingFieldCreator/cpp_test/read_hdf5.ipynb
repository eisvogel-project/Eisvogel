# %%
import h5py
import matplotlib.pyplot as plt

# %%
Ez = h5py.File('ez-000020.00.h5', 'r')
Ez_imag = Ez["ez.i"]
Ez_real = Ez["ez.r"]

# %%
eps = h5py.File('eps-000000.00.h5', 'r')["eps"][()]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)
ax.imshow(Ez_real[()])

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)
ax.imshow(eps)
